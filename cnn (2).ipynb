# %% [markdown]
# <a href="https://colab.research.google.com/gist/chpham1234/19e303cdc225c3cf70dbfe625c9510b7/cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##### Copyright 2019 The TensorFlow Authors.

# %% [markdown]
# ### Import TensorFlow

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %% [markdown]
# ### Download and prepare the CIFAR10 dataset
#
#
# The CIFAR10 dataset contains 60,000 color images in 10 classes, with 6,000 images in each class. The dataset is divided into 50,000 training images and 10,000 testing images. The classes are mutually exclusive and there is no overlap between them.

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()
train_images, test_images = train_images.astype('float32')/255.0, test_images.astype('float32')/255.0

# %% [markdown]
# ### Verify the data
#
# To verify that the dataset looks correct, let's plot the first 25 images from the training set and display the class name below each image:

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i])
    # The CIFAR labels happen to be arrays,
    # which is why you need the extra index
    plt.xlabel(class_names[train_labels[i][0]])
plt.show()

# %% [markdown]
# ### Create the convolutional base

# %%
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    zoom_range=0.1
)
datagen.fit(train_images)

# %%
model = models.Sequential([
    layers.Conv2D(64, (3,3), padding='same', activation='relu', input_shape=(32,32,3)),
    layers.BatchNormalization(),
    layers.Conv2D(64, (3,3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),
    layers.Dropout(0.3),

    layers.Conv2D(128, (3,3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.Conv2D(128, (3,3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),
    layers.Dropout(0.4),

    layers.Conv2D(256, (3,3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.Conv2D(256, (3,3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),
    layers.Dropout(0.5),

    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(10, activation='softmax'),
])
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 16, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 8, 8, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 8, 8, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 8, 8, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 8, 8, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     2,097,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,253,834 (12.41 MB)
#  Trainable params: 3,251,018 (12.40 MB)
#  Non-trainable params: 2,816 (11.00 KB)

# %% [markdown]
# ### Compile and train the model

# %%
# Compile model
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Callbacks
lr_reduction = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy', patience=5, factor=0.5, min_lr=1e-6
)

# Train model
history = model.fit(
    datagen.flow(train_images, train_labels, batch_size=64),
    epochs=100,
    validation_data=(test_images, test_labels),
    callbacks=[lr_reduction]
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 59s 57ms/step - accuracy: 0.3383 - loss: 2.1122 - val_accuracy: 0.5720 - val_loss: 1.2229 - learning_rate: 0.0010
# Epoch 2/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.5539 - loss: 1.2548 - val_accuracy: 0.6611 - val_loss: 1.0093 - learning_rate: 0.0010
# Epoch 3/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.6510 - loss: 0.9877 - val_accuracy: 0.6885 - val_loss: 0.9298 - learning_rate: 0.0010
# Epoch 4/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.6915 - loss: 0.8800 - val_accuracy: 0.6486 - val_loss: 1.0894 - learning_rate: 0.0010
# Epoch 5/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.7272 - loss: 0.7830 - val_accuracy: 0.7352 - val_loss: 0.7963 - learning_rate: 0.0010
# Epoch 6/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.7473 - loss: 0.7332 - val_accuracy: 0.7132 - val_loss: 0.8767 - learning_rate: 0.0010
# Epoch 7/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 43ms/step - accuracy: 0.7627 - loss: 0.6799 - val_accuracy: 0.7565 - val_loss: 0.7541 - learning_rate: 0.0010
# Epoch 8/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.7762 - loss: 0.6435 - val_accuracy: 0.8157 - val_loss: 0.5495 - learning_rate: 0.0010
# Epoch 9/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 43ms/step - accuracy: 0.7868 - loss: 0.6225 - val_accuracy: 0.7987 - val_loss: 0.5879 - learning_rate: 0.0010
# Epoch 10/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.7960 - loss: 0.5933 - val_accuracy: 0.7803 - val_loss: 0.6734 - learning_rate: 0.0010
# Epoch 11/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 44ms/step - accuracy: 0.8090 - loss: 0.5566 - val_accuracy: 0.8341 - val_loss: 0.4927 - learning_rate: 0.0010
# Epoch 12/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.8110 - loss: 0.5474 - val_accuracy: 0.7654 - val_loss: 0.7152 - learning_rate: 0.0010
# Epoch 13/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.8152 - loss: 0.5313 - val_accuracy: 0.8281 - val_loss: 0.5056 - learning_rate: 0.0010
# Epoch 14/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.8257 - loss: 0.5073 - val_accuracy: 0.7212 - val_loss: 0.9497 - learning_rate: 0.0010
# Epoch 15/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.8341 - loss: 0.4851 - val_accuracy: 0.8252 - val_loss: 0.5162 - learning_rate: 0.0010
# Epoch 16/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 44ms/step - accuracy: 0.8397 - loss: 0.4686 - val_accuracy: 0.8387 - val_loss: 0.4837 - learning_rate: 0.0010
# Epoch 17/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.8387 - loss: 0.4726 - val_accuracy: 0.8684 - val_loss: 0.3985 - learning_rate: 0.0010
# Epoch 18/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.8417 - loss: 0.4588 - val_accuracy: 0.8291 - val_loss: 0.5171 - learning_rate: 0.0010
# Epoch 19/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.8494 - loss: 0.4347 - val_accuracy: 0.8379 - val_loss: 0.5002 - learning_rate: 0.0010
# Epoch 20/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.8531 - loss: 0.4339 - val_accuracy: 0.8221 - val_loss: 0.5416 - learning_rate: 0.0010
# Epoch 21/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 44ms/step - accuracy: 0.8562 - loss: 0.4201 - val_accuracy: 0.8485 - val_loss: 0.4610 - learning_rate: 0.0010
# Epoch 22/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 44ms/step - accuracy: 0.8555 - loss: 0.4178 - val_accuracy: 0.8551 - val_loss: 0.4362 - learning_rate: 0.0010
# Epoch 23/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.8698 - loss: 0.3810 - val_accuracy: 0.8759 - val_loss: 0.3709 - learning_rate: 5.0000e-04
# Epoch 24/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.8768 - loss: 0.3580 - val_accuracy: 0.8721 - val_loss: 0.3875 - learning_rate: 5.0000e-04
# Epoch 25/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.8793 - loss: 0.3491 - val_accuracy: 0.8537 - val_loss: 0.4399 - learning_rate: 5.0000e-04
# Epoch 26/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.8780 - loss: 0.3510 - val_accuracy: 0.8802 - val_loss: 0.3595 - learning_rate: 5.0000e-04
# Epoch 27/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.8844 - loss: 0.3330 - val_accuracy: 0.8791 - val_loss: 0.3631 - learning_rate: 5.0000e-04
# Epoch 28/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 44ms/step - accuracy: 0.8864 - loss: 0.3253 - val_accuracy: 0.8692 - val_loss: 0.3980 - learning_rate: 5.0000e-04
# Epoch 29/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.8854 - loss: 0.3285 - val_accuracy: 0.8820 - val_loss: 0.3457 - learning_rate: 5.0000e-04
# Epoch 30/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 43ms/step - accuracy: 0.8871 - loss: 0.3239 - val_accuracy: 0.8840 - val_loss: 0.3585 - learning_rate: 5.0000e-04
# Epoch 31/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.8902 - loss: 0.3167 - val_accuracy: 0.8820 - val_loss: 0.3611 - learning_rate: 5.0000e-04
# Epoch 32/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.8924 - loss: 0.3095 - val_accuracy: 0.8959 - val_loss: 0.3203 - learning_rate: 5.0000e-04
# Epoch 33/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.8935 - loss: 0.3091 - val_accuracy: 0.8879 - val_loss: 0.3396 - learning_rate: 5.0000e-04
# Epoch 34/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.8943 - loss: 0.3040 - val_accuracy: 0.8811 - val_loss: 0.3665 - learning_rate: 5.0000e-04
# Epoch 35/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.8941 - loss: 0.3028 - val_accuracy: 0.8992 - val_loss: 0.3162 - learning_rate: 5.0000e-04
# Epoch 36/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.8968 - loss: 0.3023 - val_accuracy: 0.8954 - val_loss: 0.3167 - learning_rate: 5.0000e-04
# Epoch 37/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.8962 - loss: 0.2957 - val_accuracy: 0.8950 - val_loss: 0.3234 - learning_rate: 5.0000e-04
# Epoch 38/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.8966 - loss: 0.2932 - val_accuracy: 0.8893 - val_loss: 0.3420 - learning_rate: 5.0000e-04
# Epoch 39/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.8971 - loss: 0.2891 - val_accuracy: 0.9023 - val_loss: 0.3051 - learning_rate: 5.0000e-04
# Epoch 40/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.8985 - loss: 0.2879 - val_accuracy: 0.8989 - val_loss: 0.3114 - learning_rate: 5.0000e-04
# Epoch 41/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 44ms/step - accuracy: 0.9026 - loss: 0.2756 - val_accuracy: 0.8864 - val_loss: 0.3604 - learning_rate: 5.0000e-04
# Epoch 42/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.9043 - loss: 0.2776 - val_accuracy: 0.8952 - val_loss: 0.3247 - learning_rate: 5.0000e-04
# Epoch 43/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.8994 - loss: 0.2837 - val_accuracy: 0.9036 - val_loss: 0.2874 - learning_rate: 5.0000e-04
# Epoch 44/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 44ms/step - accuracy: 0.9030 - loss: 0.2742 - val_accuracy: 0.8941 - val_loss: 0.3311 - learning_rate: 5.0000e-04
# Epoch 45/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 44ms/step - accuracy: 0.9032 - loss: 0.2748 - val_accuracy: 0.8972 - val_loss: 0.3241 - learning_rate: 5.0000e-04
# Epoch 46/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.9074 - loss: 0.2723 - val_accuracy: 0.8953 - val_loss: 0.3297 - learning_rate: 5.0000e-04
# Epoch 47/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.9056 - loss: 0.2694 - val_accuracy: 0.8981 - val_loss: 0.3138 - learning_rate: 5.0000e-04
# Epoch 48/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.9054 - loss: 0.2717 - val_accuracy: 0.8943 - val_loss: 0.3364 - learning_rate: 5.0000e-04
# Epoch 49/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 44ms/step - accuracy: 0.9122 - loss: 0.2505 - val_accuracy: 0.9084 - val_loss: 0.2904 - learning_rate: 2.5000e-04
# Epoch 50/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.9143 - loss: 0.2443 - val_accuracy: 0.9020 - val_loss: 0.3133 - learning_rate: 2.5000e-04
# Epoch 51/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.9154 - loss: 0.2394 - val_accuracy: 0.9064 - val_loss: 0.2970 - learning_rate: 2.5000e-04
# Epoch 52/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.9142 - loss: 0.2415 - val_accuracy: 0.9084 - val_loss: 0.2850 - learning_rate: 2.5000e-04
# Epoch 53/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.9173 - loss: 0.2355 - val_accuracy: 0.9036 - val_loss: 0.3047 - learning_rate: 2.5000e-04
# Epoch 54/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.9193 - loss: 0.2330 - val_accuracy: 0.9067 - val_loss: 0.2925 - learning_rate: 2.5000e-04
# Epoch 55/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.9187 - loss: 0.2318 - val_accuracy: 0.9064 - val_loss: 0.2968 - learning_rate: 1.2500e-04
# Epoch 56/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.9213 - loss: 0.2252 - val_accuracy: 0.9075 - val_loss: 0.2933 - learning_rate: 1.2500e-04
# Epoch 57/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 43ms/step - accuracy: 0.9230 - loss: 0.2243 - val_accuracy: 0.9060 - val_loss: 0.2952 - learning_rate: 1.2500e-04
# Epoch 58/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 44ms/step - accuracy: 0.9227 - loss: 0.2219 - val_accuracy: 0.9056 - val_loss: 0.3006 - learning_rate: 1.2500e-04
# Epoch 59/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 44ms/step - accuracy: 0.9260 - loss: 0.2162 - val_accuracy: 0.9043 - val_loss: 0.3075 - learning_rate: 1.2500e-04
# Epoch 60/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.9241 - loss: 0.2185 - val_accuracy: 0.9088 - val_loss: 0.2871 - learning_rate: 6.2500e-05
# Epoch 61/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.9205 - loss: 0.2220 - val_accuracy: 0.9095 - val_loss: 0.2890 - learning_rate: 6.2500e-05
# Epoch 62/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.9281 - loss: 0.2070 - val_accuracy: 0.9091 - val_loss: 0.2877 - learning_rate: 6.2500e-05
# Epoch 63/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.9252 - loss: 0.2141 - val_accuracy: 0.9091 - val_loss: 0.2914 - learning_rate: 6.2500e-05
# Epoch 64/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.9275 - loss: 0.2051 - val_accuracy: 0.9094 - val_loss: 0.2851 - learning_rate: 6.2500e-05
# Epoch 65/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.9264 - loss: 0.2072 - val_accuracy: 0.9096 - val_loss: 0.2912 - learning_rate: 6.2500e-05
# Epoch 66/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 43ms/step - accuracy: 0.9261 - loss: 0.2092 - val_accuracy: 0.9080 - val_loss: 0.2910 - learning_rate: 6.2500e-05
# Epoch 67/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.9277 - loss: 0.2061 - val_accuracy: 0.9102 - val_loss: 0.2888 - learning_rate: 6.2500e-05
# Epoch 68/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.9280 - loss: 0.2064 - val_accuracy: 0.9124 - val_loss: 0.2804 - learning_rate: 6.2500e-05
# Epoch 69/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 44ms/step - accuracy: 0.9292 - loss: 0.2013 - val_accuracy: 0.9102 - val_loss: 0.2865 - learning_rate: 6.2500e-05
# Epoch 70/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.9284 - loss: 0.2002 - val_accuracy: 0.9101 - val_loss: 0.2889 - learning_rate: 6.2500e-05
# Epoch 71/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 44ms/step - accuracy: 0.9282 - loss: 0.2055 - val_accuracy: 0.9116 - val_loss: 0.2861 - learning_rate: 6.2500e-05
# Epoch 72/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.9260 - loss: 0.2037 - val_accuracy: 0.9102 - val_loss: 0.2885 - learning_rate: 6.2500e-05
# Epoch 73/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.9282 - loss: 0.2032 - val_accuracy: 0.9044 - val_loss: 0.3004 - learning_rate: 6.2500e-05
# Epoch 74/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.9279 - loss: 0.2048 - val_accuracy: 0.9092 - val_loss: 0.2928 - learning_rate: 3.1250e-05
# Epoch 75/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.9278 - loss: 0.2014 - val_accuracy: 0.9103 - val_loss: 0.2895 - learning_rate: 3.1250e-05
# Epoch 76/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.9287 - loss: 0.2041 - val_accuracy: 0.9095 - val_loss: 0.2905 - learning_rate: 3.1250e-05
# Epoch 77/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.9312 - loss: 0.1981 - val_accuracy: 0.9100 - val_loss: 0.2933 - learning_rate: 3.1250e-05
# Epoch 78/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 47ms/step - accuracy: 0.9275 - loss: 0.1997 - val_accuracy: 0.9114 - val_loss: 0.2873 - learning_rate: 3.1250e-05
# Epoch 79/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.9263 - loss: 0.2063 - val_accuracy: 0.9120 - val_loss: 0.2873 - learning_rate: 1.5625e-05
# Epoch 80/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.9314 - loss: 0.1950 - val_accuracy: 0.9109 - val_loss: 0.2871 - learning_rate: 1.5625e-05
# Epoch 81/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 45ms/step - accuracy: 0.9288 - loss: 0.2017 - val_accuracy: 0.9111 - val_loss: 0.2882 - learning_rate: 1.5625e-05
# Epoch 82/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.9312 - loss: 0.1988 - val_accuracy: 0.9117 - val_loss: 0.2881 - learning_rate: 1.5625e-05
# Epoch 83/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.9311 - loss: 0.1957 - val_accuracy: 0.9098 - val_loss: 0.2907 - learning_rate: 1.5625e-05
# Epoch 84/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 44ms/step - accuracy: 0.9306 - loss: 0.1976 - val_accuracy: 0.9106 - val_loss: 0.2880 - learning_rate: 7.8125e-06
# Epoch 85/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 45ms/step - accuracy: 0.9324 - loss: 0.1916 - val_accuracy: 0.9103 - val_loss: 0.2893 - learning_rate: 7.8125e-06
# Epoch 86/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - accuracy: 0.9299 - loss: 0.2003 - val_accuracy: 0.9100 - val_loss: 0.2886 - learning_rate: 7.8125e-06
# Epoch 87/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - accuracy: 0.9280 - loss: 0.2046 - val_accuracy: 0.9103 - val_loss: 0.2877 - learning_rate: 7.8125e-06
# Epoch 88/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.9334 - loss: 0.1931 - val_accuracy: 0.9105 - val_loss: 0.2910 - learning_rate: 7.8125e-06
# Epoch 89/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 44ms/step - accuracy: 0.9304 - loss: 0.1981 - val_accuracy: 0.9111 - val_loss: 0.2867 - learning_rate: 3.9063e-06
# Epoch 90/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.9295 - loss: 0.1981 - val_accuracy: 0.9104 - val_loss: 0.2903 - learning_rate: 3.9063e-06
# Epoch 91/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.9306 - loss: 0.1994 - val_accuracy: 0.9114 - val_loss: 0.2860 - learning_rate: 3.9063e-06
# Epoch 92/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.9322 - loss: 0.1923 - val_accuracy: 0.9108 - val_loss: 0.2889 - learning_rate: 3.9063e-06
# Epoch 93/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 43ms/step - accuracy: 0.9325 - loss: 0.1942 - val_accuracy: 0.9117 - val_loss: 0.2870 - learning_rate: 3.9063e-06
# Epoch 94/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.9295 - loss: 0.1988 - val_accuracy: 0.9113 - val_loss: 0.2880 - learning_rate: 1.9531e-06
# Epoch 95/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.9344 - loss: 0.1915 - val_accuracy: 0.9114 - val_loss: 0.2875 - learning_rate: 1.9531e-06
# Epoch 96/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.9318 - loss: 0.1920 - val_accuracy: 0.9111 - val_loss: 0.2880 - learning_rate: 1.9531e-06
# Epoch 97/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.9295 - loss: 0.1964 - val_accuracy: 0.9115 - val_loss: 0.2880 - learning_rate: 1.9531e-06
# Epoch 98/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 43ms/step - accuracy: 0.9300 - loss: 0.1988 - val_accuracy: 0.9114 - val_loss: 0.2882 - learning_rate: 1.9531e-06
# Epoch 99/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.9313 - loss: 0.1954 - val_accuracy: 0.9108 - val_loss: 0.2893 - learning_rate: 1.0000e-06
# Epoch 100/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 44ms/step - accuracy: 0.9318 - loss: 0.1940 - val_accuracy: 0.9111 - val_loss: 0.2862 - learning_rate: 1.0000e-06

# %% [markdown]
# ### Evaluate the model

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
# Out:
# 313/313 - 1s - 4ms/step - accuracy: 0.9111 - loss: 0.2862

# %%
print(test_acc)
# Out:
# 0.9110999703407288

# %%
img_height = 32
img_width = 32

url = "https://img.freepik.com/free-photo/airplane-flying-cloudy-sky_144627-132.jpg"
path = tf.keras.utils.get_file(origin=url)

img = tf.keras.utils.load_img(path, target_size=(img_height, img_width))
img_array = tf.keras.utils.img_to_array(img)
img_array = img_array / 255.0
img_array = tf.expand_dims(img_array, 0)   # shape=(1, 32, 32, 3)

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to '{}' "
    "with a {:.2f}% confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# This image most likely belongs to 'airplane' with a 23.11% confidence.

# %% [markdown]
# Your simple CNN has achieved a test accuracy of over 70%. Not bad for a few lines of code! For another CNN style, check out the [TensorFlow 2 quickstart for experts](https://www.tensorflow.org/tutorials/quickstart/advanced) example that uses the Keras subclassing API and `tf.GradientTape`.

# %%
model.save('TeamHestia_CIFARmodel.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# !python test_image.py
# Out:
# 2025-04-27 02:01:47.952291: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745719307.970967   47580 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745719307.976577   47580 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-27 02:01:52.495211: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I0000 00:00:1745719312.495396   47580 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 12800 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1745719313.903048   47618 service.cc:148] XLA service 0x7ea9a0003630 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1745719313.903089   47618 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1745719313.980686   47618 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1745719314.876591   47618 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# /content/test_image.py:51: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print('\nPrediction: This image most likely belongs to ' + class_names[int(result.argmax(axis=-1))])
#
# Prediction: This image most likely belongs to cat
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# /content/test_image.py:65: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print('\nPrediction: This image most likely belongs to ' + class_names[int(result.argmax(axis=-1))])
#
# Prediction: This image most likely belongs to airplane
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# /content/test_image.py:79: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print('\nPrediction: This image most likely belongs to ' + class_names[int(result.argmax(axis=-1))])
#
# Prediction: This image most likely belongs to automobile
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# /content/test_image.py:93: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print('\nPrediction: This image most likely belongs to ' + class_names[int(result.argmax(axis=-1))])
#
# Prediction: This image most likely belongs to ship
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# /content/test_image.py:108: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print('\nPrediction: This image most likely belongs to ' + class_names[int(result.argmax(axis=-1))])
#
# Prediction: This image most likely belongs to cat
